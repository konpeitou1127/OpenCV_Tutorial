# %% [markdown]
# ## 初期設定

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 画像の読み込み
# ### カラーで読み込む

# %%
img = cv2.imread('./img/Lenna.png')
print(img.shape)
# Out:
# (512, 512, 3)

# %% [markdown]
# ### グレースケールで読み込む

# %%
gray_img = cv2.imread('./img/Lenna.png', 0)
print(gray_img.shape)
# Out:
# (512, 512)

# %% [markdown]
# ### 画像の表示

# %%
convert_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.title('カラー画像')
plt.imshow(convert_img)

plt.subplot(1,2,2)
plt.title('グレースケール画像')
plt.imshow(gray_img, cmap='gray')
plt.show()

# %% [markdown]
# ## 色空間の変換

# %%
# BGR→YUV
yuv_img = cv2.cvtColor(img , cv2.COLOR_BGR2YUV)
# BGR→HSV
hsv_img = cv2.cvtColor(img , cv2.COLOR_BGR2HSV)
# BGR→RGB
rgb_img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
# BGR→グレースケール
gray_img = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## 拡大・縮小

# %%
print(img.shape)
small_img = cv2.resize(rgb_img, None, fx=0.1, fy=0.1, interpolation=cv2.INTER_CUBIC)
print(small_img.shape)
big_img = cv2.resize(rgb_img, None, fx=2.0, fy=2.0, interpolation=cv2.INTER_CUBIC)
print(big_img.shape)
plt.subplot(1,2,1)
plt.title('縮小した画像')
plt.imshow(small_img)

plt.subplot(1,2,2)
plt.title('拡大した画像')
plt.imshow(big_img)
plt.show()
# Out:
# (512, 512, 3)
# (51, 51, 3)
# (1024, 1024, 3)

# %% [markdown]
# ## フィルタ処理

# %% [markdown]
# ### ガウシアンフィルタ

# %%
gaussian_img = cv2.GaussianBlur(gray_img,(11,11),0)

plt.subplot(1,2,1)
plt.title('元画像')
plt.imshow(gray_img, cmap='gray')

plt.subplot(1,2,2)
plt.title('ガウシアンフィルタ適用後')
plt.imshow(gaussian_img, cmap='gray')
plt.show()

# %% [markdown]
# ### Cannyフィルタ

# %%
canny_img = cv2.Canny(gray_img, 100,200)

plt.subplot(1,2,1)
plt.title('元画像')
plt.imshow(gray_img, cmap='gray')

plt.subplot(1,2,2)
plt.title('Cannyフィルタ適用後')
plt.imshow(canny_img, cmap='gray')
plt.show()

# %% [markdown]
# ### バイラテラルフィルタ

# %%
bilateral_img = cv2.bilateralFilter(gray_img,9,75,75)
plt.subplot(1,2,1)
plt.title('元画像')
plt.imshow(gray_img, cmap='gray')

plt.subplot(1,2,2)
plt.title('バイラテラルフィルタ適用後')
plt.imshow(bilateral_img, cmap='gray')
plt.show()

# %% [markdown]
# ## Sobel フィルタ

# %% [markdown]
# ## ラプラシアンフィルタ

# %% [markdown]
# ## 画像の2値化

# %%
# 画像のしきい値処理を行う関数
ret, bi_img = cv2.threshold(gray_img, 125, 255, cv2.THRESH_BINARY)
# 画像の表示
plt.subplot(1,2,1)
plt.title('元画像')
plt.imshow(gray_img, cmap='gray')

plt.subplot(1,2,2)
plt.title('2値化処理後')
plt.imshow(bi_img, cmap='gray')
plt.show()

# %% [markdown]
# ## マスク処理

# %%
mask_img = cv2.imread('./img/mask.png')
masked_img = cv2.bitwise_and(convert_img, mask_img)
plt.subplot(1,3,1)
plt.title('元画像')
plt.imshow(convert_img)
plt.subplot(1,3,2)
plt.title('マスク画像')
plt.imshow(mask_img, cmap='gray')
plt.subplot(1,3,3)
plt.title('結果画像')
plt.imshow(masked_img)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 色空間の変換としきい値処理による抽出

# %%
color_circle_img = hsv_img = cv2.cvtColor(cv2.imread('./img/munsell-color-system.png'), cv2.COLOR_BGR2RGB)
hsv_img = cv2.cvtColor(color_circle_img, cv2.COLOR_RGB2HSV)

h_img = hsv_img[:, :, 0]
h, w, ch = color_circle_img.shape
mask_img2 = np.ones((h, w), dtype=np.uint8)
mask_img2[h_img < 90] = 0
mask_img2[h_img > 140] = 0
print(mask_img2.shape)

masked_img = cv2.bitwise_and(color_circle_img, color_circle_img, mask=mask_img2)

plt.subplot(1,3,1)
plt.title('元画像')
plt.imshow(color_circle_img)
plt.subplot(1,3,2)
plt.title('マスク画像')
plt.imshow(mask_img2, cmap='gray')
plt.subplot(1,3,3)
plt.title('結果画像')
plt.imshow(masked_img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-65d4ff64a3d0> in <module>()
# ----> 1 color_circle_img = hsv_img = cv2.cvtColor(cv2.imread('./img/munsell-color-system.png'), cv2.COLOR_BGR2RGB)
#       2 hsv_img = cv2.cvtColor(color_circle_img, cv2.COLOR_RGB2HSV)
#       3
#       4 h_img = hsv_img[:, :, 0]
#       5 h, w, ch = color_circle_img.shape
#
# error: C:\bld\opencv_1489524617654\work\opencv-3.1.0\modules\imgproc\src\color.cpp:7341: error: (-215) scn == 3 || scn == 4 in function cv::ipp_cvtColor

# %% [markdown]
# ## 画像の保存
